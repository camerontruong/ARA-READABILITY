# %% [markdown]
# <a href="https://colab.research.google.com/github/camerontruong/ARA-READABILITY/blob/main/ImpliedCostofCapital.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install fix-yahoo-finance==0.1.30
# !pip install yfinance
# Out:
# Collecting fix-yahoo-finance==0.1.30
#   Downloading fix-yahoo-finance-0.1.30.tar.gz (11 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from fix-yahoo-finance==0.1.30) (1.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from fix-yahoo-finance==0.1.30) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fix-yahoo-finance==0.1.30) (2.23.0)
# Requirement already satisfied: multitasking in /usr/local/lib/python3.7/dist-packages (from fix-yahoo-finance==0.1.30) (0.0.10)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->fix-yahoo-finance==0.1.30) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->fix-yahoo-finance==0.1.30) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->fix-yahoo-finance==0.1.30) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->fix-yahoo-finance==0.1.30) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fix-yahoo-finance==0.1.30) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->fix-yahoo-finance==0.1.30) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->fix-yahoo-finance==0.1.30) (2.10)
# Building wheels for collected packages: fix-yahoo-finance
#   Building wheel for fix-yahoo-finance (setup.py) ... done
#   Created wheel for fix-yahoo-finance: filename=fix_yahoo_finance-0.1.30-py3-none-any.whl size=12156 sha256=de34bb9b514bbb951b74fcee373e4024f4686449c5f7ad457164bcfb0810814e
#   Stored in directory: /root/.cache/pip/wheels/56/aa/91/bf3efdfaa5f1d39aa13325848db30ed4cb17113a1f500bbbe9
# Successfully built fix-yahoo-finance
# Installing collected packages: fix-yahoo-finance
#   Attempting uninstall: fix-yahoo-finance
#     Found existing installation: fix-yahoo-finance 0.0.22
#     Uninstalling fix-yahoo-finance-0.0.22:
#       Successfully uninstalled fix-yahoo-finance-0.0.22
# Successfully installed fix-yahoo-finance-0.1.30
# Collecting yfinance
#   Downloading yfinance-0.1.70-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Collecting requests>=2.26
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.5 MB/s
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Collecting lxml>=4.5.1
#   Downloading lxml-4.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 12.0 MB/s
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Installing collected packages: requests, lxml, yfinance
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed lxml-4.8.0 requests-2.27.1 yfinance-0.1.70

# %%
#RETRIEVE FINANCIAL DATA FROM YAHOO FINANCE FOR ASX LISTED FIRMS

import yfinance as yf
tick=input("What firm would you like to derive the implied cost of capital? \n").upper()
firm =yf.Ticker(f"{tick}.AX")
B=firm.info['bookValue']
g=0.025
ROE=firm.info['returnOnEquity']
V=firm.info['currentPrice']
#Seed discount value
r=g+0.000001
TEMP=round(B+((ROE-r)/(r-g))*B,2)
diff=round(abs(V-TEMP),2)
# print(TEMP,diff)
mcap=round(firm.info['marketCap']/1000000000,2)
print(f"{tick} company name is {firm.info['longName']}")
print(f"{tick} is the sector of {firm.info['sector']}")
print(f"{tick} Market Cap (in billion) is $ {mcap}")
print(f"{tick} Market Beta is {round(firm.info['beta'],2)}")
print(f"{tick} ROE is {round(firm.info['returnOnEquity'],4): .2%}")
print(f"{tick} Book Value is {firm.info['bookValue']}")
print(f"{tick} Market Price is $ {firm.info['currentPrice']}")
# print(f"{tick} Market Cap is $ {firm.info['marketCap']}")
# print(mcap)
# print(firm.info)
# Out:
# What firm would you like to derive the implied cost of capital?
# BHP
# BHP company name is BHP Group Limited
# BHP is the sector of Basic Materials
# BHP Market Cap (in billion) is $ 335.76
# BHP Market Beta is 0.78
# BHP ROE is  33.16%
# BHP Book Value is 10.035
# BHP Market Price is $ 46.8

# %%
#EMPLOY ITERATIONS TO DERIVE THE DISCOUNT RATE FOR THE ONE-STAGE RESIDUAL INCOME MODEL

iter=0
while diff>0.0001 and TEMP>V:
    r+=0.00001
    TEMP=round(B+((ROE-r)/(r-g))*B,2)
    diff=round(abs(V-TEMP),2)
    #print(r,TEMP,diff)
    cost="{:.3%}".format(r)
    iter+=1

print(f"The implied cost of capital of {tick} is {r: .2%} after {iter} iterations to derive a market value of $ {TEMP}")
# Out:
# The implied cost of capital of BHP is  9.08% after 6575 iterations to derive a market value of $ 46.8

# %%
#FULL RUN
#RETRIEVE FINANCIAL DATA FROM YAHOO FINANCE FOR ASX LISTED FIRMS
#EMPLOY ITERATIONS TO DERIVE THE DISCOUNT RATE FOR THE ONE-STAGE RESIDUAL INCOME MODEL
tick=input("What firm would you like to derive the implied cost of capital? \n")
firm =yf.Ticker(f"{tick}.AX")
mcap=round(firm.info['marketCap']/1000000000,2)
print(f"{tick} company name is {firm.info['longName']}")
print(f"{tick} is the sector of {firm.info['sector']}")
print(f"{tick} Market Cap (in billion) is $ {mcap}")
print(f"{tick} Market Beta is {round(firm.info['beta'],2)}")
print(f"{tick} ROE is {round(firm.info['returnOnEquity'],4): .2%}")
print(f"{tick} Book Value is {firm.info['bookValue']}")
print(f"{tick} Market Price is $ {firm.info['currentPrice']}")


B=firm.info['bookValue']
g=0.025
ROE=firm.info['returnOnEquity']
V=firm.info['currentPrice']
#Seed discount value
r=g+0.000001
TEMP=round(B+((ROE-r)/(r-g))*B,2)
diff=round(abs(V-TEMP),2)

iter=0

while diff>0.0001 and TEMP>V:
    r+=0.00001
    TEMP=round(B+((ROE-r)/(r-g))*B,2)
    diff=round(abs(V-TEMP),2)
    cost="{:.3%}".format(r)
    iter+=1

print(f"The implied cost of capital of {tick} is {r: .2%} after {iter} iterations to derive a market value of $ {TEMP}")
# Out:
# What firm would you like to derive the implied cost of capital?
# NAB
# NAB company name is National Australia Bank Limited
# NAB is the sector of Financial Services
# NAB Market Cap (in billion) is $ 103.23
# NAB Market Beta is 0.91
# NAB ROE is  10.43%
# NAB Book Value is 19.163
# NAB Market Price is $ 31.62
# The implied cost of capital of NAB is  7.31% after 4806 iterations to derive a market value of $ 31.62

# %%
# ALLOW a PANEL of FIRMs
#FULL RUN
tick=input("What firms would you like to derive the implied cost of capital, seperated by comma? \n")
names=tick.split(",")
# names=["ANZ","NAB","CBA","BOQ","BHP","FMG","RIO","JHX","BSL","NCM","NST","CSL","BPT","STO","WPL","RMD","NCK","SUL","TWE","WOW","COL",
#        "SUN","ALL","GNC","CGF","RHC","AWC","RRL","NHC","ARB","APX","RFF","TLS","IGO","WTC","LLC","WES","LYC","EVN","IEL","JBH","HVN",
#        "NUF","MIN","DOW","A2M","SSM","AIA","AMC","ASX","COH","FPH","MGR","REA","REH","SEK","SHL",
#        "SGP","TAH","WBC"]
names = list(dict.fromkeys(names))
print(names)


beta=[]
marketcap=[]
cost=[]
year=[]
compname=[]
sector=[]
for name in names:
    firm =yf.Ticker(f"{name}.AX")
    # print(f"{name} ROE is {firm.info['returnOnEquity']}")
    # print(f"{name} Book Value is {firm.info['bookValue']}")
    # print(f"{name} Market Price is $ {firm.info['regularMarketPrice']}")


    B=firm.info['bookValue']
    g=0.025
    ROE=firm.info['returnOnEquity']
    V=firm.info['regularMarketPrice']
    #Seed discount value
    r=g+0.000001
    TEMP=round(B+((ROE-r)/(r-g))*B,2)
    diff=round(abs(V-TEMP),2)
    # print(TEMP,diff)
    beta.append(firm.info['beta'])
    marketcap.append(round(firm.info['marketCap']/1000000000,2))
    year.append(2022)
    compname.append(firm.info['longName'])
    sector.append(firm.info['sector'])

    iter=0

    while diff>0.0001 and TEMP>V:
        r+=0.00001
        TEMP=round(B+((ROE-r)/(r-g))*B,2)
        diff=round(abs(V-TEMP),2)
        #print(r,TEMP,diff)
        # cost="{:.3%}".format(r)
        iter+=1
    
       
    cost.append(r) 

    print(f"The implied cost of capital of {name} is {r: .2%} after {iter} iterations to derive a market value of $ {TEMP}")
# Out:
# What firms would you like to derive the implied cost of capital, seperated by comma?
# ANZ,CBA,NAB,WBC,MQG
# ['ANZ', 'CBA', 'NAB', 'WBC', 'MQG']
# The implied cost of capital of ANZ is  8.74% after 6236 iterations to derive a market value of $ 26.76
# The implied cost of capital of CBA is  7.05% after 4546 iterations to derive a market value of $ 102.39
# The implied cost of capital of NAB is  7.31% after 4806 iterations to derive a market value of $ 31.62
# The implied cost of capital of WBC is  6.87% after 4368 iterations to derive a market value of $ 23.83
# The implied cost of capital of MQG is  8.30% after 5800 iterations to derive a market value of $ 186.89

# %%
import pandas as pd
df = pd.DataFrame(
    {'TICKER': names,
     'Company Name':compname,
     'Sector':sector,
     'Year':year,  
     'Beta': beta,
     'Market Cap': marketcap,
     'Implied Cost of Equity Capital': cost,
    })

import plotly.express as px

fig = px.scatter(df.query("Year==2022"), x="Beta", y="Implied Cost of Equity Capital",
	         size="Market Cap", color="Company Name",
                 hover_name="Company Name", log_x=True, size_max=60)
fig.show()
df.style.format(
    {
    'Implied Cost of Equity Capital': '{:,.2%}'.format,
})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e8703753-f9b6-407a-b888-e43474737f3c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8703753-f9b6-407a-b888-e43474737f3c")) {                    Plotly.newPlot(                        "e8703753-f9b6-407a-b888-e43474737f3c",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Company Name=Australia and New Zealand Banking Group Limited<br>Beta=%{x}<br>Implied Cost of Equity Capital=%{y}<br>Market Cap=%{marker.size}<extra></extra>","hovertext":["Australia and New Zealand Banking Group Limited"],"legendgroup":"Australia and New Zealand Banking Group Limited","marker":{"color":"#636efa","size":[74.77],"sizemode":"area","sizeref":0.04849444444444445,"symbol":"circle"},"mode":"markers","name":"Australia and New Zealand Banking Group Limited","orientation":"v","showlegend":true,"x":[0.900053],"xaxis":"x","y":[0.08736099999999968],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Company Name=Commonwealth Bank of Australia<br>Beta=%{x}<br>Implied Cost of Equity Capital=%{y}<br>Market Cap=%{marker.size}<extra></extra>","hovertext":["Commonwealth Bank of Australia"],"legendgroup":"Commonwealth Bank of Australia","marker":{"color":"#EF553B","size":[174.58],"sizemode":"area","sizeref":0.04849444444444445,"symbol":"circle"},"mode":"markers","name":"Commonwealth Bank of Australia","orientation":"v","showlegend":true,"x":[0.734366],"xaxis":"x","y":[0.07046100000000623],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Company Name=National Australia Bank Limited<br>Beta=%{x}<br>Implied Cost of Equity Capital=%{y}<br>Market Cap=%{marker.size}<extra></extra>","hovertext":["National Australia Bank Limited"],"legendgroup":"National Australia Bank Limited","marker":{"color":"#00cc96","size":[103.23],"sizemode":"area","sizeref":0.04849444444444445,"symbol":"circle"},"mode":"markers","name":"National Australia Bank Limited","orientation":"v","showlegend":true,"x":[0.907001],"xaxis":"x","y":[0.07306100000000522],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Company Name=Westpac Banking Corporation<br>Beta=%{x}<br>Implied Cost of Equity Capital=%{y}<br>Market Cap=%{marker.size}<extra></extra>","hovertext":["Westpac Banking Corporation"],"legendgroup":"Westpac Banking Corporation","marker":{"color":"#ab63fa","size":[83.33],"sizemode":"area","sizeref":0.04849444444444445,"symbol":"circle"},"mode":"markers","name":"Westpac Banking Corporation","orientation":"v","showlegend":true,"x":[0.802779],"xaxis":"x","y":[0.06868100000000692],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Company Name=Macquarie Group Limited<br>Beta=%{x}<br>Implied Cost of Equity Capital=%{y}<br>Market Cap=%{marker.size}<extra></extra>","hovertext":["Macquarie Group Limited"],"legendgroup":"Macquarie Group Limited","marker":{"color":"#FFA15A","size":[72.47],"sizemode":"area","sizeref":0.04849444444444445,"symbol":"circle"},"mode":"markers","name":"Macquarie Group Limited","orientation":"v","showlegend":true,"x":[1.108498],"xaxis":"x","y":[0.08300100000000137],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white" ...
# <style type="text/css">
# </style>
# <table id="T_8bc35_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >TICKER</th>
#       <th class="col_heading level0 col1" >Company Name</th>
#       <th class="col_heading level0 col2" >Sector</th>
#       <th class="col_heading level0 col3" >Year</th>
#       <th class="col_heading level0 col4" >Beta</th>
#       <th class="col_heading level0 col5" >Market Cap</th>
#       <th class="col_heading level0 col6" >Implied Cost of Equity Capital</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8bc35_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8bc35_row0_col0" class="data row0 col0" >ANZ</td>
#       <td id="T_8bc35_row0_col1" class="data row0 col1" >Australia and New Zealand Banking Group Limited</td>
#       <td id="T_8bc35_row0_col2" class="data row0 col2" >Financial Services</td>
#       <td id="T_8bc35_row0_col3" class="data row0 col3" >2022</td>
#       <td id="T_8bc35_row0_col4" class="data row0 col4" >0.900053</td>
#       <td id="T_8bc35_row0_col5" class="data row0 col5" >74.770000</td>
#       <td id="T_8bc35_row0_col6" class="data row0 col6" >8.74%</td>
#     </tr>
#     <tr>
#       <th id="T_8bc35_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8bc35_row1_col0" class="data row1 col0" >CBA</td>
#       <td id="T_8bc35_row1_col1" class="data row1 col1" >Commonwealth Bank of Australia</td>
#       <td id="T_8bc35_row1_col2" class="data row1 col2" >Financial Services</td>
#       <td id="T_8bc35_row1_col3" class="data row1 col3" >2022</td>
#       <td id="T_8bc35_row1_col4" class="data row1 col4" >0.734366</td>
#       <td id="T_8bc35_row1_col5" class="data row1 col5" >174.580000</td>
#       <td id="T_8bc35_row1_col6" class="data row1 col6" >7.05%</td>
#     </tr>
#     <tr>
#       <th id="T_8bc35_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8bc35_row2_col0" class="data row2 col0" >NAB</td>
#       <td id="T_8bc35_row2_col1" class="data row2 col1" >National Australia Bank Limited</td>
#       <td id="T_8bc35_row2_col2" class="data row2 col2" >Financial Services</td>
#       <td id="T_8bc35_row2_col3" class="data row2 col3" >2022</td>
#       <td id="T_8bc35_row2_col4" class="data row2 col4" >0.907001</td>
#       <td id="T_8bc35_row2_col5" class="data row2 col5" >103.230000</td>
#       <td id="T_8bc35_row2_col6" class="data row2 col6" >7.31%</td>
#     </tr>
#     <tr>
#       <th id="T_8bc35_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8bc35_row3_col0" class="data row3 col0" >WBC</td>
#       <td id="T_8bc35_row3_col1" class="data row3 col1" >Westpac Banking Corporation</td>
#       <td id="T_8bc35_row3_col2" class="data row3 col2" >Financial Services</td>
#       <td id="T_8bc35_row3_col3" class="data row3 col3" >2022</td>
#       <td id="T_8bc35_row3_col4" class="data row3 col4" >0.802779</td>
#       <td id="T_8bc35_row3_col5" class="data row3 col5" >83.330000</td>
#       <td id="T_8bc35_row3_col6" class="data row3 col6" >6.87%</td>
#     </tr>
#     <tr>
#       <th id="T_8bc35_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8bc35_row4_col0" class="data row4 col0" >MQG</td>
#       <td id="T_8bc35_row4_col1" class="data row4 col1" >Macquarie Group Limited</td>
#       <td id="T_8bc35_row4_col2" class="data row4 col2" >Financial Services</td>
#       <td id="T_8bc35_row4_col3" class="data row4 col3" >2022</td>
#       <td id="T_8bc35_row4_col4" class="data row4 col4" >1.108498</td>
#       <td id="T_8bc35_row4_col5" class="data row4 col5" >72.470000</td>
#       <td id="T_8bc35_row4_col6" class="data row4 col6" >8.30%</td>
#     </tr>
#   </tbody>
# </table>

# %%
import pandas as pd
df=pd.read_csv('/content/ASX_ICC.csv')
# df = pd.DataFrame(
#     {'TICKER': names,
#      'Beta': beta,
#      'Market Cap': marketcap,
#      'Implied Cost of Equity Capital': cost,
#      'Year':year,
#      'Company Name':compname
#     })

import plotly.express as px
# df = px.data.gapminder()

fig = px.scatter(df.query("Year==2022"), x="Beta", y="Implied Cost of Equity Capital",
	         size="Market Cap", color="Company Name",
                 hover_name="Company Name", log_x=True, 
                 range_y=[0,0.25], size_max=60,
                 )
                 
fig.show()

df.style.format({
    'Implied Cost of Equity Capital': '{:,.2%}'.format,
})
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c0ef0241-3829-4af2-ac13-a60113ec9479" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c0ef0241-3829-4af2-ac13-a60113ec9479")) {                    Plotly.newPlot(                        "c0ef0241-3829-4af2-ac13-a60113ec9479",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Company Name=Australia and New Zealand Banking Group Limited<br>Beta=%{x}<br>Implied Cost of Equity Capital=%{y}<br>Market Cap=%{marker.size}<extra></extra>","hovertext":["Australia and New Zealand Banking Group Limited"],"legendgroup":"Australia and New Zealand Banking Group Limited","marker":{"color":"#636efa","size":[75.86],"sizemode":"area","sizeref":0.066725,"symbol":"circle"},"mode":"markers","name":"Australia and New Zealand Banking Group Limited","orientation":"v","showlegend":true,"x":[0.916989],"xaxis":"x","y":[0.0870109999999998],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Company Name=National Australia Bank Limited<br>Beta=%{x}<br>Implied Cost of Equity Capital=%{y}<br>Market Cap=%{marker.size}<extra></extra>","hovertext":["National Australia Bank Limited"],"legendgroup":"National Australia Bank Limited","marker":{"color":"#EF553B","size":[105.4],"sizemode":"area","sizeref":0.066725,"symbol":"circle"},"mode":"markers","name":"National Australia Bank Limited","orientation":"v","showlegend":true,"x":[0.92695],"xaxis":"x","y":[0.0721210000000055],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Company Name=Commonwealth Bank of Australia<br>Beta=%{x}<br>Implied Cost of Equity Capital=%{y}<br>Market Cap=%{marker.size}<extra></extra>","hovertext":["Commonwealth Bank of Australia"],"legendgroup":"Commonwealth Bank of Australia","marker":{"color":"#00cc96","size":[176.97],"sizemode":"area","sizeref":0.066725,"symbol":"circle"},"mode":"markers","name":"Commonwealth Bank of Australia","orientation":"v","showlegend":true,"x":[0.706696],"xaxis":"x","y":[0.0645610000000085],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Company Name=Bank of Queensland Limited<br>Beta=%{x}<br>Implied Cost of Equity Capital=%{y}<br>Market Cap=%{marker.size}<extra></extra>","hovertext":["Bank of Queensland Limited"],"legendgroup":"Bank of Queensland Limited","marker":{"color":"#ab63fa","size":[5.03],"sizemode":"area","sizeref":0.066725,"symbol":"circle"},"mode":"markers","name":"Bank of Queensland Limited","orientation":"v","showlegend":true,"x":[0.973754],"xaxis":"x","y":[0.081371000000002],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Company Name=BHP Group Limited<br>Beta=%{x}<br>Implied Cost of Equity Capital=%{y}<br>Market Cap=%{marker.size}<extra></extra>","hovertext":["BHP Group Limited"],"legendgroup":"BHP Group Limited","marker":{"color":"#FFA15A","size":[240.21],"sizemode":"area","sizeref":0.066725,"symbol":"circle"},"mode":"markers","name":"BHP Group Limited","orientation":"v","showlegend":true,"x":[0.772897],"xaxis":"x","y":[0.0729810000000052],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Company Name=Fortescue Metals Group Limited<br>Beta=%{x}<br>Implied Cost of Equity Capital=%{y}<br>Market Cap=%{marker.size}<extra></extra>","hovertext":["Fortescue Metals Group Limited"],"legendgroup":"Fortescue Metals Group Limited","marker":{"color":"#19d3f3","size":[64.13],"sizemode":"area","sizeref":0.066725,"symbol":"circle"},"mode":"markers","name":"Fortescue Metals Group Limited","orientation":"v","showlegend":true,"x":[0.694521],"xaxis":"x","y":[0.2018710000000619],"yaxis":"y","type":"scatter"},{"hovertemplate":"<b>%{hovertext}</b><br><br>Company Name=Rio Tinto Group<br>Beta=%{x}<br>Implied Cost of Equity Capital=%{y}< ...
# <style type="text/css">
# </style>
# <table id="T_8e5ce_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Unnamed: 0</th>
#       <th class="col_heading level0 col1" >TICKER</th>
#       <th class="col_heading level0 col2" >Company Name</th>
#       <th class="col_heading level0 col3" >Sector</th>
#       <th class="col_heading level0 col4" >Year</th>
#       <th class="col_heading level0 col5" >Beta</th>
#       <th class="col_heading level0 col6" >Market Cap</th>
#       <th class="col_heading level0 col7" >Implied Cost of Equity Capital</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8e5ce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8e5ce_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_8e5ce_row0_col1" class="data row0 col1" >ANZ</td>
#       <td id="T_8e5ce_row0_col2" class="data row0 col2" >Australia and New Zealand Banking Group Limited</td>
#       <td id="T_8e5ce_row0_col3" class="data row0 col3" >Financial Services</td>
#       <td id="T_8e5ce_row0_col4" class="data row0 col4" >2022</td>
#       <td id="T_8e5ce_row0_col5" class="data row0 col5" >0.916989</td>
#       <td id="T_8e5ce_row0_col6" class="data row0 col6" >75.860000</td>
#       <td id="T_8e5ce_row0_col7" class="data row0 col7" >8.70%</td>
#     </tr>
#     <tr>
#       <th id="T_8e5ce_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8e5ce_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_8e5ce_row1_col1" class="data row1 col1" >NAB</td>
#       <td id="T_8e5ce_row1_col2" class="data row1 col2" >National Australia Bank Limited</td>
#       <td id="T_8e5ce_row1_col3" class="data row1 col3" >Financial Services</td>
#       <td id="T_8e5ce_row1_col4" class="data row1 col4" >2022</td>
#       <td id="T_8e5ce_row1_col5" class="data row1 col5" >0.926950</td>
#       <td id="T_8e5ce_row1_col6" class="data row1 col6" >105.400000</td>
#       <td id="T_8e5ce_row1_col7" class="data row1 col7" >7.21%</td>
#     </tr>
#     <tr>
#       <th id="T_8e5ce_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8e5ce_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_8e5ce_row2_col1" class="data row2 col1" >CBA</td>
#       <td id="T_8e5ce_row2_col2" class="data row2 col2" >Commonwealth Bank of Australia</td>
#       <td id="T_8e5ce_row2_col3" class="data row2 col3" >Financial Services</td>
#       <td id="T_8e5ce_row2_col4" class="data row2 col4" >2022</td>
#       <td id="T_8e5ce_row2_col5" class="data row2 col5" >0.706696</td>
#       <td id="T_8e5ce_row2_col6" class="data row2 col6" >176.970000</td>
#       <td id="T_8e5ce_row2_col7" class="data row2 col7" >6.46%</td>
#     </tr>
#     <tr>
#       <th id="T_8e5ce_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8e5ce_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_8e5ce_row3_col1" class="data row3 col1" >BOQ</td>
#       <td id="T_8e5ce_row3_col2" class="data row3 col2" >Bank of Queensland Limited</td>
#       <td id="T_8e5ce_row3_col3" class="data row3 col3" >Financial Services</td>
#       <td id="T_8e5ce_row3_col4" class="data row3 col4" >2022</td>
#       <td id="T_8e5ce_row3_col5" class="data row3 col5" >0.973754</td>
#       <td id="T_8e5ce_row3_col6" class="data row3 col6" >5.030000</td>
#       <td id="T_8e5ce_row3_col7" class="data row3 col7" >8.14%</td>
#     </tr>
#     <tr>
#       <th id="T_8e5ce_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8e5ce_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_8e5ce_row4_col1" class="data row4 col1" >BHP</td>
#       <td id="T_8e5ce_row4_col2" class="data row4 col2" >BHP Group Limited</td>
#       <td id="T_8e5ce_row4_col3" class="data row4 col3" >Basic Materials</td>
#       <td id="T_8e5ce_row4_col4" class="data row4 col4" >2022</td>
#       <td id="T_8e5ce_row4_col5" class="data row4 col5" >0.772897</td>
#       <td id="T_8e5ce_row4_col6" class="data row4 col6" >240.210000</td>
#       <td id="T_8e5ce_row4_col7" class="data row4 col7" >7.30%</td>
#     </tr>
#     <tr>
#       <th id="T_8e5ce_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8e5ce_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_8e5ce_row5_col1" class="data row5 col1" >FMG</td>
#       <td id="T_8e5ce_row5_col2" class="data row5 col2" >Fortescue Metals Group Limited</td>
#       <td id="T_8e5ce_row5_col3" class="data row5 col3" >Basic Materials</td>
#       <td id="T_8e5ce_row5_col4" class="data row5 col4" >2022</td>
#       <td id="T_8e5ce_row5_col5" class="data row5 col5" >0.694521</td>
#       <td id="T_8e5ce_row5_col6" class="data row5 col6" >64.130000</td>
#       <td id="T_8e5ce_row5_col7" class="data row5 col7" >20.19%</td>
#     </tr>
#     <tr>
#       <th id="T_8e5ce_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_8e5ce_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_8e5ce_row6_col1" class="data row6 col1" >RIO</td>
#       <td id="T_8e5ce_row6_col2" class="data row6 col2" >Rio Tinto Group</td>
#       <td id="T_8e5ce_row6_col3" class="data row6 col3" >Basic Materials</td>
#       <td id="T_8e5ce_row6_col4" class="data row6 col4" >2022</td>
#       <td id="T_8e5ce_row6_col5" class="data row6 col5" >0.624792</td>
#       <td id="T_8e5ce_row6_col6" class="data row6 col6" >180.690000</td>
#       <td id="T_8e5ce_row6_col7" class="data row6 col7" >13.30%</td>
#     </tr>
#     <tr>
#       <th id="T_8e5ce_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_8e5ce_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_8e5ce_row7_col1" class="data row7 col1" >JHX</td>
#       <td id="T_8e5ce_row7_col2" class="data row7 col2" >James Hardie Industries plc</td>
#       <td id="T_8e5ce_row7_col3" class="data row7 col3" >Basic Materials</td>
#       <td id="T_8e5ce_row7_col4" class="data row7 col4" >2022</td>
#       <td id="T_8e5ce_row7_col5" class="data row7 col5" >1.023242</td>
#       <td id="T_8e5ce_row7_col6" class="data row7 col6" >18.430000</td>
#       <td id="T_8e5ce_row7_col7" class="data row7 col7" >4.83%</td>
#     </tr>
#     <tr>
#       <th id="T_8e5ce_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_8e5ce_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_8e5ce_row8_col1" class="data row8 col1" >BSL</td>
#       <td id="T_8e5ce_row8_col2" class="data row8 col2" >BlueScope Steel Limited</td>
#       <td id="T_8e5ce_row8_col3" class="data row8 col3" >Basic Materials</td>
#       <td id="T_8e5ce_row8_col4" class="data row8 col4" >2022</td>
#       <td id="T_8e5ce_row8_col5" class="data row8 col5" >1.441860</td>
#       <td id="T_8e5ce_row8_col6" class="data row8 col6" >9.520000</td>
#       <td id="T_8e5ce_row8_col7" class="data row8 col7" >13.86%</td>
#     </tr>
#     <tr>
#       <th id="T_8e5ce_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_8e5ce_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_8e5ce_row9_col1" class="data row9 col1" >NCM</td>
#       <td id="T_8e5ce_row9_col2" class="data row9 col2" >Newcrest Mining Limited</td>
#       <td id="T_8e5ce_row9_col3" class="data row9 col3" >Basic Materials</td>
#       <td id="T_8e5ce_row9_col4" class="data row9 col4" >2022</td>
#       <td id="T_8e5ce_row9_col5" class="data row9 col5" >0.448256</td>
#       <td id="T_8e5ce_row9_col6" class="data row9 col6" >21.990000</td>
#       <td id="T_8e5ce_row9_col7" class="data row9 col7" >7.09%</td>
#     </tr>
#     <tr>
#       <th id="T_8e5ce_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_8e5ce_row10_col0" class="data row10 col0" >10</td>
#       <td id="T_8e5ce_row10_col1" class="data row10 col1" >NST</td>
#       <td id="T_8e5ce_row10_col2" class="data row10 col2" >Northern Star Resources Limited</td>
#       <td id="T_8e5ce_row10_col3" class="data row10 col3" >Basic Materials</td>
#       <td id="T_8e5ce_row10_col4" class="data row10 col4" >2022</td>
#       <td id="T_8e5ce_row10_col5" class="data row10 col5" >-0.059767</td>
#       <td id="T_8e5ce_row10_col6" class="data row10 col6" >11.250000</td>
#       <td id="T_8e5ce_row10_

# %%
dfc=[]
icc=df.groupby('Sector', as_index=False)['Implied Cost of Equity Capital'].mean()
beta=df.groupby('Sector', as_index=False)['Beta'].mean()
mcap=df.groupby('Sector', as_index=False)['Market Cap'].mean()
dfs=(icc.merge(beta, on='Sector')).merge(mcap,on='Sector')
dfs['Year']=2022
import plotly.express as px
# df = px.data.gapminder()

fig = px.scatter(dfs.query("Year==2022"), x="Beta", y="Implied Cost of Equity Capital",
	         size="Market Cap", color="Sector",
                 hover_name="Sector", log_x=True, 
                 range_y=[0,0.14], size_max=120,
                 )
                 
fig.show()

dfs.style.format({
    'Implied Cost of Equity Capital': '{:,.2%}'.format,
})
dfs.style.format({
    'Implied Cost of Equity Capital': '{:,.2%}'.format,
})

# %%
import numpy as np
import statsmodels.api as sm
df = df.dropna()

X = np.log10(df["Market Cap"]) ## log of market cap

y = df["Implied Cost of Equity Capital"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statisticsfrom google.colab import files

df.to_csv('output.csv', encoding = 'utf-8-sig') 
files.download('output.csv')
model.summary()

# %%
import numpy as np
import statsmodels.api as sm
df = df.dropna()

X = df["Beta"] ## log of market cap

y = df["Implied Cost of Equity Capital"] ## Y usually means our output/dependent variable
X = sm.add_constant(X) ## let's add an intercept (beta_0) to our model

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()

# %%
from google.colab import files

df.to_csv('ASX_ICC.csv', encoding = 'utf-8-sig') 
files.download('ASX_ICC.csv')

# %%
# tick=input("What firm would you like to derive the implied cost of capital? \n").upper()
# firm =yf.Ticker(f"{tick}")
# firm.info
# B=firm.info['bookValue']
# g=0.025
# ROE=firm.info['returnOnEquity']
# V=firm.info['currentPrice']
# #Seed discount value
# r=g+0.000001
# TEMP=round(B+((ROE-r)/(r-g))*B,2)
# diff=round(abs(V-TEMP),2)
# # print(TEMP,diff)
# mcap=round(firm.info['marketCap']/1000000000,2)
# print(f"{tick} Name is {firm.info['longName']}")
# print(f"{tick} Market Cap (in billion) is $ {mcap}")
# print(f"{tick} Market Beta is {round(firm.info['beta'],2)}")
# print(f"{tick} ROE is {round(firm.info['returnOnEquity'],4): .2%}")
# print(f"{tick} Book Value is {firm.info['bookValue']}")
# print(f"{tick} Market Price is $ {firm.info['currentPrice']}")

# %%
# AsiaPac Equity	RSX	14.06%
# AsiaPac Equity	FXI	11.43%
# AsiaPac Equity	EWY	9.63%
# AsiaPac Equity	EWT	9.54%
# AsiaPac Equity	AAXJ	9.19%
# AsiaPac Equity	EWS	8.60%
# AsiaPac Equity	EPI	8.23%
# AsiaPac Equity	EWM	7.29%
# AsiaPac Equity	EWH	7.23%
# AsiaPac Equity	EWA	7.17%
# AsiaPac Equity	INDA	6.69%
# Consumer Discretionary
# FXD	7.77%
# Consumer Discretionary
# XRT	7.64%
# Consumer Discretionary
# XLY	7.26%
# Consumer Discretionary
# VCR	7.11%
# Consumer Discretionary
# IYC	7.02%
# Consumer Discretionary
# RTH	6.69%
# Consumer Staples	IYK	7.37%
# Consumer Staples	FXG	6.93%
# Consumer Staples	VDC	6.83%
# Consumer Staples	XLP	6.82%
# Consumer Staples	ECON	6.81%
# Emerging | Frontier	FM	11.10%
# Emerging | Frontier	EWZ	9.87%
# Emerging | Frontier	EEM	9.63%
# Emerging | Frontier	VWO	9.41%
# Emerging | Frontier	GAF	8.90%
# Emerging | Frontier	ECH	8.15%
# Emerging | Frontier	EWW	7.44%
# Energy	IPW	5.98%
# Energy	IXC	5.49%
# Energy	IYE	5.23%
# Energy	VDE	5.22%
# Energy	OIH	5.21%
# Energy	XLE	5.18%
# Energy	XOP	4.22%
# Europe Equity	EWD	8.19%
# Europe Equity	EWP	7.98%
# Europe Equity	FEZ	7.75%
# Europe Equity	HEDJ	7.57%
# Europe Equity	EZU	7.56%
# Europe Equity	VGK	7.44%
# Europe Equity	EWQ	7.39%
# Europe Equity	EWU	7.30%
# Europe Equity	EWI	7.05%
# Europe Equity	EWL	6.77%
# Financials	KIE	8.52%
# Financials	IYG	8.45%
# Financials	KBE	7.93%
# Financials	XLF	7.90%
# Financials	KRE	7.69%
# Global Equity	VEU	7.82%
# Global Equity	VXUS	7.81%
# Global Equity	DGT	7.77%
# Global Equity	ACWI	7.53%
# Healthcare	XLV	7.15%
# Healthcare	IBB	6.72%
# Industrial	IYT	9.77%
# Industrial	XLI	8.17%
# Industrial	VIS	8.01%
# Industrial	IYJ	7.51%
# Large Cap	VOO	7.38%
# Large Cap	IVV	7.36%
# Large Cap	SPY	7.36%
# Large Cap	IWB	7.31%
# Materials	XHB	8.21%
# Materials	XLB	7.97%
# Materials	MOO	7.93%
# Materials	LIT	7.29%
# Materials	GUNR	6.27%
# Materials	IGE	5.09%
# Materials	XME	4.93%
# Mid Cap	MDY	6.90%
# Mid Cap	VO	6.88%
# Mid Cap	IJH	6.87%
# Mid Cap	IWR	6.84%
# Precious Metals Miners
# GDXJ	6.08%
# Precious Metals Miners
# GDX	3.71%
# Real Estate	RWX	5.67%
# Real Estate	RWO	4.65%
# Real Estate	IYR	4.60%
# Real Estate	VNQ	4.09%
# Real Estate	RWR	3.97%
# Small Cap	VB	6.73%
# Small Cap	IWM	6.71%
# Small Cap	IJR	6.54%
# Technology	XLK	7.65%
# Technology	SMH	7.51%
# Technology	HACK	5.82%
# Technology	FDN	4.70%
# Telecom	IXP	8.24%
# Telecom	VOX	8.04%
# Telecom	IYZ	5.92%
# Utilities	XLU	7.30%
# Utilities	IDU	7.18%
# Utilities	VPU	7.16%

# %%
# !pip install dash
# Out:
# Collecting dash
#   Downloading dash-2.3.1-py3-none-any.whl (9.6 MB)
#      |████████████████████████████████| 9.6 MB 4.2 MB/s
# Collecting dash-html-components==2.0.0
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-table==5.0.0
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Collecting flask-compress
#   Downloading Flask_Compress-1.12-py3-none-any.whl (7.9 kB)
# Requirement already satisfied: Flask>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from dash) (1.1.4)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from dash) (5.5.0)
# Collecting dash-core-components==2.0.0
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.4->dash) (7.1.2)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.4->dash) (1.0.1)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.4->dash) (2.11.3)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=1.0.4->dash) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly>=5.0.0->dash) (8.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly>=5.0.0->dash) (1.15.0)
# Collecting brotli
#   Downloading Brotli-1.0.9-cp37-cp37m-manylinux1_x86_64.whl (357 kB)
#      |████████████████████████████████| 357 kB 55.7 MB/s
# Installing collected packages: brotli, flask-compress, dash-table, dash-html-components, dash-core-components, dash
# Successfully installed brotli-1.0.9 dash-2.3.1 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 flask-compress-1.12

# %%
# import dash
# import dash_core_components as dcc
# import dash_html_components as html
# import plotly.graph_objs as go
# import pandas as pd

# df = pd.read_excel(
#     "https://github.com/chris1610/pbpython/blob/master/data/salesfunnel.xlsx?raw=True"
# )

# pv = pd.pivot_table(df, index=['Name'], columns=["Status"], values=['Quantity'], aggfunc=sum, fill_value=0)


# trace1 = go.Bar(x=pv.index, y=pv[('Quantity', 'declined')], name='Declined')
# trace2 = go.Bar(x=pv.index, y=pv[('Quantity', 'pending')], name='Pending')
# trace3 = go.Bar(x=pv.index, y=pv[('Quantity', 'presented')], name='Presented')
# trace4 = go.Bar(x=pv.index, y=pv[('Quantity', 'won')], name='Won')

# app = dash.Dash()
# app.layout = html.Div(children=[
#     html.H1(children='Sales Funnel Report'),
#     html.Div(children='''National Sales Funnel Report.'''),
#     dcc.Graph(
#         id='example-graph',
#         figure={
#             'data': [trace1, trace2, trace3, trace4],
#             'layout':
#             go.Layout(title='Order Status by Customer', barmode='stack')
#         })
# ])

# if __name__ == '__main__':
#     app.run_server(debug=True)
